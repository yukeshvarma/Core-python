# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-4b6a0d09-ac7c-4b88-a09e-88f49ffde7ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4b6a0d09-ac7c-4b88-a09e-88f49ffde7ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("world_population.csv")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
#setting index by column
df.set_index('Country',inplace=True)

# %%
df
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
df.loc['Algeria']
# Out:
# Rank                                   34
# CCA3                                  DZA
# Capital                           Algiers
# Continent                          Africa
# 2022 Population                44903225.0
# 2020 Population                43451666.0
# 2015 Population                39543154.0
# 2010 Population                35856344.0
# 2000 Population                30774621.0
# 1990 Population                25518074.0
# 1980 Population                18739378.0
# 1970 Population                13795915.0
# Area (km²)                      2381741.0
# Density (per km²)                 18.8531
# Growth Rate                        1.0164
# World Population Percentage          0.56
# Name: Algeria, dtype: object

# %%
df.iloc[1]
# Out:
# Rank                                 138
# CCA3                                 ALB
# Capital                           Tirana
# Continent                         Europe
# 2022 Population                2842321.0
# 2020 Population                2866849.0
# 2015 Population                2882481.0
# 2010 Population                2913399.0
# 2000 Population                3182021.0
# 1990 Population                3295066.0
# 1980 Population                2941651.0
# 1970 Population                2324731.0
# Area (km²)                       28748.0
# Density (per km²)                98.8702
# Growth Rate                       0.9957
# World Population Percentage         0.04
# Name: Albania, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                Country  Rank CCA3           Capital Continent  \
# 0          Afghanistan    36  AFG             Kabul      Asia
# 1              Albania   138  ALB            Tirana    Europe
# 2              Algeria    34  DZA           Algiers    Africa
# 3       American Samoa   213  ASM         Pago Pago   Oceania
# 4              Andorra   203  AND  Andorra la Vella    Europe
# ..                 ...   ...  ...               ...       ...
# 229  Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230     Western Sahara   172  ESH          El Aaiún    Africa
# 231              Yemen    46  YEM             Sanaa      Asia
# 232             Zambia    63  ZMB            Lusaka    Africa
# 233           Zimbabwe    74  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df.set_index(['Continent','Country'],inplace=True)

# %%
df
# Out:
#                              Rank CCA3           Capital  2022 Population  \
# Continent Country
# Asia      Afghanistan          36  AFG             Kabul       41128771.0
# Europe    Albania             138  ALB            Tirana        2842321.0
# Africa    Algeria              34  DZA           Algiers       44903225.0
# Oceania   American Samoa      213  ASM         Pago Pago          44273.0
# Europe    Andorra             203  AND  Andorra la Vella          79824.0
# ...                           ...  ...               ...              ...
# Oceania   Wallis and Futuna   226  WLF          Mata-Utu          11572.0
# Africa    Western Sahara      172  ESH          El Aaiún         575986.0
# Asia      Yemen                46  YEM             Sanaa       33696614.0
# Africa    Zambia               63  ZMB            Lusaka       20017675.0
#           Zimbabwe             74  ZWE            Harare       16320537.0
#
# ...

# %%
df.sort_index(ascending=[False,True])
#pd.set_option('display.max.rows',234)
# Out:
#                               Rank CCA3       Capital  2022 Population  \
# Continent     Country
# South America Argentina         33  ARG  Buenos Aires       45510318.0
#               Bolivia           80  BOL         Sucre       12224110.0
#               Brazil             7  BRA      Brasilia      215313498.0
#               Chile             65  CHL      Santiago       19603733.0
#               Colombia          28  COL        Bogota       51874024.0
# ...                            ...  ...           ...              ...
# Africa        Tunisia           79  TUN         Tunis       12356117.0
#               Uganda            31  UGA       Kampala       47249585.0
#               Western Sahara   172  ESH      El Aaiún         575986.0
#               Zambia            63  ZMB        Lusaka       20017675.0
#               Zimbabwe          74  ZWE        Harare       16320537.0
#
#                               2020 Population  2015 Population  \
# Continent     Country
# ...

# %%
df.loc['Asia']
# Out:
#                       Rank CCA3              Capital  2022 Population  \
# Country
# Afghanistan             36  AFG                Kabul     4.112877e+07
# Armenia                140  ARM              Yerevan     2.780469e+06
# Azerbaijan              91  AZE                 Baku     1.035807e+07
# Bahrain                154  BHR               Manama     1.472233e+06
# Bangladesh               8  BGD                Dhaka     1.711864e+08
# Bhutan                 165  BTN              Thimphu     7.824550e+05
# Brunei                 175  BRN  Bandar Seri Begawan     4.490020e+05
# Cambodia                73  KHM           Phnom Penh     1.676784e+07
# China                    1  CHN              Beijing     1.425887e+09
# Georgia                131  GEO              Tbilisi     3.744385e+06
# Hong Kong              104  HKG            Hong Kong     7.488865e+06
# India                    2  IND            New Delhi     1.417173e+09
# ...

# %%
df.loc['Asia','India']
# Out:
# Rank                                      2
# CCA3                                    IND
# Capital                           New Delhi
# 2022 Population                1417173173.0
# 2020 Population                1396387127.0
# 2015 Population                1322866505.0
# 2010 Population                1240613620.0
# 2000 Population                1059633675.0
# 1990 Population                         NaN
# 1980 Population                         NaN
# 1970 Population                 557501301.0
# Area (km²)                        3287590.0
# Density (per km²)                  431.0675
# Growth Rate                          1.0068
# World Population Percentage           17.77
# Name: (Asia, India), dtype: object

# %% [markdown]
# GROUPING

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#     Continent            Country  Rank CCA3           Capital  \
# 0        Asia        Afghanistan    36  AFG             Kabul
# 1      Europe            Albania   138  ALB            Tirana
# 2      Africa            Algeria    34  DZA           Algiers
# 3     Oceania     American Samoa   213  ASM         Pago Pago
# 4      Europe            Andorra   203  AND  Andorra la Vella
# ..        ...                ...   ...  ...               ...
# 229   Oceania  Wallis and Futuna   226  WLF          Mata-Utu
# 230    Africa     Western Sahara   172  ESH          El Aaiún
# 231      Asia              Yemen    46  YEM             Sanaa
# 232    Africa             Zambia    63  ZMB            Lusaka
# 233    Africa           Zimbabwe    74  ZWE            Harare
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
groupby_conti = df.groupby(['Continent'])

# %%
groupby_conti.count()
# Out:
#                Country  Rank  CCA3  Capital  2022 Population  2020 Population  \
# Continent
# Africa              57    57    57       57               56               57
# Asia                50    50    50       50               49               49
# Europe              50    50    50       50               49               50
# North America       40    40    40       40               40               40
# Oceania             23    23    23       23               22               23
# South America       14    14    14       14               14               14
#
#                2015 Population  2010 Population  2000 Population  \
# Continent
# Africa                      54               54               56
# Asia                        50               47               46
# Europe                      49               50               49
# North America               40               40               40
# Oceania                     23               23               23
# ...

# %%
groupby_conti.sum()
# Out:
# <ipython-input-28-28941cd90ef2>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   groupby_conti.sum()
#                Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa         5253     1.425529e+09     1.360672e+09     1.156664e+09
# Asia           3878     4.720042e+09     4.652802e+09     4.458250e+09
# Europe         6225     7.377132e+08     7.457922e+08     7.363453e+08
# North America  6437     6.002961e+08     5.942366e+08     5.703838e+08
# Oceania        4336     4.502050e+07     4.393343e+07     4.040328e+07
# South America  1366     4.368166e+08     4.315300e+08     4.131344e+08
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa            1.020503e+09     8.175085e+08     6.371100e+08
# ...

# %%
df.groupby('Continent').agg({'World Population Percentage':['sum','count','mean','max','min']})
# Out:
#               World Population Percentage
#                                       sum count      mean    max   min
# Continent
# Africa                              17.87    57  0.313509   2.74  0.00
# Asia                                59.19    50  1.183800  17.88  0.01
# Europe                               9.33    50  0.186600   1.81  0.00
# North America                        7.51    40  0.187750   4.24  0.00
# Oceania                              0.55    23  0.023913   0.33  0.00
# South America                        5.48    14  0.391429   2.70  0.00

# %%
df.groupby('Continent').agg({'Country':['count','describe']})
# Out:
#               Country
#                 count describe
#               Country    count unique             top freq
# Continent
# Africa             57       57     57         Algeria    1
# Asia               50       50     50     Afghanistan    1
# Europe             50       50     50         Albania    1
# North America      40       40     40        Anguilla    1
# Oceania            23       23     23  American Samoa    1
# South America      14       14     14       Argentina    1

# %%
df.groupby(['Rank','Continent','Country']).max()
# Out:
#                                     CCA3           Capital  2022 Population  \
# Rank Continent     Country
# 1    Asia          China             CHN           Beijing     1.425887e+09
# 2    Asia          India             IND         New Delhi     1.417173e+09
# 3    North America United States     USA  Washington, D.C.     3.382899e+08
# 4    Asia          Indonesia         IDN           Jakarta     2.755013e+08
# 5    Asia          Pakistan          PAK         Islamabad     2.358249e+08
# ...                                  ...               ...              ...
# 230  North America Montserrat        MSR            Brades     4.390000e+03
# 231  South America Falkland Islands  FLK           Stanley     3.780000e+03
# 232  Oceania       Niue              NIU             Alofi     1.934000e+03
# 233  Oceania       Tokelau           TKL          Nukunonu     1.871000e+03
# 234  Europe        Vatican City      VAT      Vatican City     5.100000e+02
#
# ...
