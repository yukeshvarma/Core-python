# %%
from google.colab import files
data=files.upload()
# Out:
#      <input type="file" id="files-1e2e5a98-f954-4b5d-b273-d2f878d73792" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1e2e5a98-f954-4b5d-b273-d2f878d73792">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('world_population.csv')

# %%
df.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia       41128771.0
# 1   138  ALB         Albania            Tirana    Europe        2842321.0
# 2    34  DZA         Algeria           Algiers    Africa       44903225.0
# 3   213  ASM  American Samoa         Pago Pago   Oceania          44273.0
# 4   203  AND         Andorra  Andorra la Vella    Europe          79824.0
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       38972230.0       33753499.0       28189672.0       19542982.0
# 1        2866849.0        2882481.0        2913399.0        3182021.0
# 2       43451666.0       39543154.0       35856344.0       30774621.0
# 3          46189.0          51368.0          54849.0          58230.0
# 4          77700.0          71746.0          71519.0          66097.0
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df.shape
# Out:
# (234, 17)

# %%
df
# Out:
#      Rank CCA3                           Country              Capital  \
# 0      36  AFG                       Afghanistan                Kabul
# 1     138  ALB                           Albania               Tirana
# 2      34  DZA                           Algeria              Algiers
# 3     213  ASM                    American Samoa            Pago Pago
# 4     203  AND                           Andorra     Andorra la Vella
# 5      42  AGO                            Angola               Luanda
# 6     224  AIA                          Anguilla           The Valley
# 7     201  ATG               Antigua and Barbuda         Saint John’s
# 8      33  ARG                         Argentina         Buenos Aires
# 9     140  ARM                           Armenia              Yerevan
# 10    198  ABW                             Aruba           Oranjestad
# 11     55  AUS                         Australia             Canberra
# ...

# %%
# Set the maximum number of rows to display
#df=pd.set_option('display.max.rows',None)

# %%
'''import pandas as pd

# Example DataFrame
data = {'A': range(100),
        'B': range(100),
        'C': range(100)}

df = pd.DataFrame(data)

# Set the maximum number of rows to display to None (display all rows)
pd.set_option('display.max_rows', None)

# Display the DataFrame
print(df)'''
# Out:
# "import pandas as pd\n\n# Example DataFrame\ndata = {'A': range(100),\n        'B': range(100),\n        'C': range(100)}\n\ndf = pd.DataFrame(data)\n\n# Set the maximum number of rows to display to None (display all rows)\npd.set_option('display.max_rows', None)\n\n# Display the DataFrame\nprint(df)"

# %%
#sorting
df[df['Rank'] <= 10].sort_values(by='Rank',ascending=True)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# 92      1.417173e+09     1.396387e+09     1.322867e+09     1.240614e+09
# ...

# %%
df[df['Rank'] <= 10].sort_values(by=['Continent','Country'],ascending=[True,False])
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 92      2  IND          India         New Delhi           Asia
# 41      1  CHN          China           Beijing           Asia
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
# 131    10  MEX         Mexico       Mexico City  North America
# 27      7  BRA         Brazil          Brasilia  South America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 149     2.185412e+08     2.083274e+08     1.839958e+08     1.609529e+08
# 156     2.358249e+08     2.271967e+08     2.109693e+08     1.944545e+08
# ...

# %%
specific_country=['India','Pakistan']
df[df['Country'].isin(specific_country)]
# Out:
#      Rank CCA3   Country    Capital Continent  2022 Population  \
# 92      2  IND     India  New Delhi      Asia     1.417173e+09
# 156     5  PAK  Pakistan  Islamabad      Asia     2.358249e+08
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 92      1.396387e+09     1.322867e+09     1.240614e+09     1.059634e+09
# 156     2.271967e+08     2.109693e+08     1.944545e+08     1.543699e+08
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# 92               NaN              NaN      557501301.0   3287590.0
# 156      115414069.0       80624057.0       59290872.0    881912.0
#
#      Density (per km²)  Growth Rate  World Population Percentage
# 92            431.0675       1.0068                        17.77
# 156           267.4018       1.0191                         2.96

# %%
'''# Example list
my_list = [1, 2, 3, 2, 4, 5, 3, 6, 6]

# Convert list to set to remove duplicates
unique_elements = set(my_list)

# Find duplicates by comparing lengths
duplicates = [item for item in unique_elements if my_list.count(item) > 1]

print("Duplicate values:", duplicates)'''
# Out:
# Duplicate values: [2, 3, 6]

# %%
df[df['Continent'].str.contains('Asia')]
# Out:
#      Rank CCA3               Country              Capital Continent  \
# 0      36  AFG           Afghanistan                Kabul      Asia
# 9     140  ARM               Armenia              Yerevan      Asia
# 13     91  AZE            Azerbaijan                 Baku      Asia
# 15    154  BHR               Bahrain               Manama      Asia
# 16      8  BGD            Bangladesh                Dhaka      Asia
# 23    165  BTN                Bhutan              Thimphu      Asia
# 29    175  BRN                Brunei  Bandar Seri Begawan      Asia
# 33     73  KHM              Cambodia           Phnom Penh      Asia
# 41      1  CHN                 China              Beijing      Asia
# 73    131  GEO               Georgia              Tbilisi      Asia
# 89    104  HKG             Hong Kong            Hong Kong      Asia
# 92      2  IND                 India            New Delhi      Asia
# 93      4  IDN             Indonesia              Jakarta      Asia
# ...

# %%
Asia_Continent=df[df['Continent'].str.contains('Asia')]
count=len(Asia_Continent)
count
# Out:
# 50

# %%
df2=df.set_index('Rank')

# %%
df2
# Out:
#      CCA3                           Country              Capital  \
# Rank
# 36    AFG                       Afghanistan                Kabul
# 138   ALB                           Albania               Tirana
# 34    DZA                           Algeria              Algiers
# 213   ASM                    American Samoa            Pago Pago
# 203   AND                           Andorra     Andorra la Vella
# 42    AGO                            Angola               Luanda
# 224   AIA                          Anguilla           The Valley
# 201   ATG               Antigua and Barbuda         Saint John’s
# 33    ARG                         Argentina         Buenos Aires
# 140   ARM                           Armenia              Yerevan
# 198   ABW                             Aruba           Oranjestad
# 55    AUS                         Australia             Canberra
# 99    AUT                           Austria               Vienna
# ...

# %%
#filtering
df2.filter(items = ['Growth Rate','Country','Capital'],axis=1)
# Out:
#       Growth Rate                           Country              Capital
# Rank
# 36         1.0257                       Afghanistan                Kabul
# 138        0.9957                           Albania               Tirana
# 34         1.0164                           Algeria              Algiers
# 213        0.9831                    American Samoa            Pago Pago
# 203        1.0100                           Andorra     Andorra la Vella
# 42         1.0315                            Angola               Luanda
# 224        1.0066                          Anguilla           The Valley
# 201        1.0058               Antigua and Barbuda         Saint John’s
# 33         1.0052                         Argentina         Buenos Aires
# 140        0.9962                           Armenia              Yerevan
# 198        0.9991                             Aruba           Oranjestad
# 55         1.0099                         Australia             Canberra
# ...

# %%
df2.filter(items = [2],axis=0)
# Out:
#      CCA3 Country    Capital Continent  2022 Population  2020 Population  \
# Rank
# 2     IND   India  New Delhi      Asia     1.417173e+09     1.396387e+09
#
#       2015 Population  2010 Population  2000 Population  1990 Population  \
# Rank
# 2        1.322867e+09     1.240614e+09     1.059634e+09              NaN
#
#       1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# Rank
# 2                 NaN      557501301.0   3287590.0           431.0675
#
#       Growth Rate  World Population Percentage
# Rank
# 2          1.0068                        17.77

# %%
df2.loc[3	]#this is indexing with values
# Out:
# CCA3                                        USA
# Country                           United States
# Capital                        Washington, D.C.
# Continent                         North America
# 2022 Population                     338289857.0
# 2020 Population                     335942003.0
# 2015 Population                     324607776.0
# 2010 Population                     311182845.0
# 2000 Population                     282398554.0
# 1990 Population                     248083732.0
# 1980 Population                     223140018.0
# 1970 Population                     200328340.0
# Area (km²)                            9372610.0
# Density (per km²)                       36.0935
# Growth Rate                              1.0038
# World Population Percentage                4.24
# Name: 3, dtype: object

# %%
df2.iloc[3]#this is indexing with random index
# Out:
# CCA3                                      ASM
# Country                        American Samoa
# Capital                             Pago Pago
# Continent                             Oceania
# 2022 Population                       44273.0
# 2020 Population                       46189.0
# 2015 Population                       51368.0
# 2010 Population                       54849.0
# 2000 Population                       58230.0
# 1990 Population                       47818.0
# 1980 Population                       32886.0
# 1970 Population                       27075.0
# Area (km²)                              199.0
# Density (per km²)                    222.4774
# Growth Rate                            0.9831
# World Population Percentage               0.0
# Name: 213, dtype: object
